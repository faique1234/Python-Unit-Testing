# %%
# first import unit test module
import unittest
def square(number):
 return number ** 2


def double(number):
  return number *2
# CReate a test class for testing
class Testsquare(unittest.TestCase) :
  def test1(self):
    self.assertEqual(square(4),(16))
  def test2(self):
    self.assertEqual(square(5.0),(25.0))
  def test3(self):
    self.assertEqual(square(-2), (4))

class Testdouble(unittest.TestCase):
  def test1(self):
    self.assertEqual(double(4),(8))
  def test2 (self):
    self.assertEqual(double(3.0),(6.0))
  def test3(self):
    self.assertEqual(double(-6),(-12))
unittest.main(argv=[''],verbosity=2,exit=False)
# Out:
# test1 (__main__.Testdouble.test1) ... ok
# test2 (__main__.Testdouble.test2) ... ok
# test3 (__main__.Testdouble.test3) ... ok
# test1 (__main__.Testpwr.test1) ... ok
# test2 (__main__.Testpwr.test2) ... ok
# test1 (__main__.Testsquare.test1) ... ok
# test2 (__main__.Testsquare.test2) ... ok
# test3 (__main__.Testsquare.test3) ... ok
#
# ----------------------------------------------------------------------
# Ran 8 tests in 0.015s
#
# OK

# %%
# firt import the unit test library in python
import unittest
#building up a function
def pwr(n):
  return n**n
# created a class for unit testin
class Testpwr(unittest.TestCase):
  # test function
  def test1(self):
    self.assertEqual(pwr(2),(4))
  # test function
  def test2(self):
    self.assertEqual(pwr(3),(27))
unittest.main(argv=[''],verbosity=2, exit = False)
# Out:
# test1 (__main__.Testdouble.test1) ... ok
# test2 (__main__.Testdouble.test2) ... ok
# test3 (__main__.Testdouble.test3) ... ok
# test1 (__main__.Testpwr.test1) ... ok
# test2 (__main__.Testpwr.test2) ... ok
# test1 (__main__.Testsquare.test1) ... ok
# test2 (__main__.Testsquare.test2) ... ok
# test3 (__main__.Testsquare.test3) ... ok
#
# ----------------------------------------------------------------------
# Ran 8 tests in 0.015s
#
# OK
